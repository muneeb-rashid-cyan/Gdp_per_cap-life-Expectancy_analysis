# %% [markdown]
# # Lab 4. My first data science project

# %% [markdown]
# ## In this lab you will apply the concepts and techniques developed in sessions 1-6.
#
# ## You are expected to submit the code developed as well as a brief description of your findings and insights for each assigment.
#
# ## You can do this by creating [markdown cells](https://www.tutorialspoint.com/jupyter/jupyter_notebook_markdown_cells.htm#:~:text=%20Jupyter%20Notebook%20-%20Markdown%20Cells%20%201,To%20attach%20link%20to%20text%2C%20place...%20More%20) in jupyter notebook, and writting in them.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
### Let's load the gapminder dataset
gapminder = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ### (1) Use pairplot to visualise the data. Colour code data points by the continent they are from.

# %%
sns.pairplot(gapminder,hue='continent')

# %% [markdown]
# ### (2) What patterns can you see? Are there any outliars?

# %% [markdown]
# There is no linear relation between any feature of dataset and distribution of any feature is not normal , distribution of GDP Per Capita and population is right skewed and range of year column is between 1952 to 2007
#
# And there is not many some outliers in the dataset, outliers are those datapoints that laying far away from others trend of datapoints

# %% [markdown]
# ### (3) Filter the dataset to find rows in which life GDP per capita is greater than 60,000

# %%
gapminder_filtered = gapminder[gapminder['gdpPercap'] > 60000]

# %%
gapminder_filtered
# Out:
#     country continent  year  lifeExp     pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565  160000  108382.35290
# 853  Kuwait      Asia  1957   58.033  212846  113523.13290
# 854  Kuwait      Asia  1962   60.470  358266   95458.11176
# 855  Kuwait      Asia  1967   64.624  575003   80894.88326
# 856  Kuwait      Asia  1972   67.712  841934  109347.86700

# %% [markdown]
# ### (4) What does this tell us about the data, as seen in the question (1)  pairplot?

# %% [markdown]
# The asia continent is perform differently. Blue data points belong to asia and all the outliers belong to asia so its mean Gdp per capita and life expectancy of asia is different as compared to other continent. The population of asia is also increasing with the passage of time and population of others continent is stable

# %% [markdown]
# ### (5) Find the rows in the dataframe with the top 20 life expectancies

# %%
gapminder_20=gapminder.nlargest(20, 'lifeExp')

# %%
gapminder_20
# Out:
#                country continent  year  lifeExp        pop    gdpPercap
# 803              Japan      Asia  2007   82.603  127467972  31656.06806
# 671   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 802              Japan      Asia  2002   82.000  127065841  28604.59190
# 695            Iceland    Europe  2007   81.757     301931  36180.78919
# 1487       Switzerland    Europe  2007   81.701    7554661  37506.41907
# 670   Hong Kong, China      Asia  2002   81.495    6762476  30209.01516
# 71           Australia   Oceania  2007   81.235   20434176  34435.36744
# 1427             Spain    Europe  2007   80.941   40448191  28821.06370
# 1475            Sweden    Europe  2007   80.884    9031088  33859.74835
# 767             Israel      Asia  2007   80.745    6426679  25523.27710
# 801              Japan      Asia  1997   80.690  125956499  28816.58499
# 539             France    Europe  2007   80.657   61083916  30470.01670
# ...

# %% [markdown]
# ### (6) Plot the evolution of life expectancy, population and GDP per capita of Kuwait

# %%
gapminder_filtered_kuwait = gapminder[gapminder['country'] =='Kuwait']

# %%
gapminder_filtered_kuwait.head()
# Out:
#     country continent  year  lifeExp     pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565  160000  108382.35290
# 853  Kuwait      Asia  1957   58.033  212846  113523.13290
# 854  Kuwait      Asia  1962   60.470  358266   95458.11176
# 855  Kuwait      Asia  1967   64.624  575003   80894.88326
# 856  Kuwait      Asia  1972   67.712  841934  109347.86700

# %%
x=gapminder_filtered_kuwait.lifeExp
y=gapminder_filtered_kuwait['pop']
z=gapminder_filtered_kuwait.gdpPercap

# %%
plt.plot(x, color = 'blue', linewidth=3, linestyle='dashed')
plt.title("Evolution of Life Expectancy of Kuwait",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Evolution of Life Expectancy of Kuwait')

# %%
plt.plot(y, color = 'blue', linewidth=3, linestyle='dashed')
plt.title("Evolution of Population of kuwait",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Evolution of Population of kuwait')

# %%
plt.plot(z, color = 'blue', linewidth=3, linestyle='dashed')
plt.title("Evolution of GDP Per Capita of Kuwait",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Evolution of GDP Per Capita of Kuwait')

# %% [markdown]
# The life expectancy of kuwait country is linearly increasing with the passage of time and popultion of kuwait is also increasing with the passage of time but its also decrease for some years and then again it grpws linearly. The GDP per Capita hve no smooth trend it fluctuate all the years and mostly it decrease linearly

# %% [markdown]
# ### (7) Visualise the distribution of GDP per capita of countries and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# #### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# #### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
p=sns.displot(gapminder, x="lifeExp",y='gdpPercap',hue='continent',height=4, aspect=1.5)
p.fig.set_dpi(150)
p.fig.suptitle("Distribution of GDP PER Capita and Life Expectancy",fontsize=10)
# Out:
# Text(0.5, 0.98, 'Distribution of GDP PER Capita and Life Expectancy')

# %% [markdown]
# The distribution of GDP per Capita is right skewed so its not normal most of the values lies in 0 to 10000 so thatswhy the mode is in the beginning.

# %% [markdown]
# The distribution of life expectancy is not normal and there is more then one peak in this distribution so its bimodel distribution and the mode of this distrbution is 70 and mean is also close to it but distrbution is not skewed.

# %%
sns.set(rc = {'figure.figsize':(15,8)})
r=sns.regplot(x="gdpPercap", y="lifeExp", data=gapminder);
r.set_title("Regression Line  of Life Expectancy and GDP Per Capita",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Regression Line  of Life Expectancy and GDP Per Capita')

# %% [markdown]
# The relation between the Gdp Per Capita and life Expectancy is not linear so when i draw the regression line between them most of the gdp is right skewed so there is no relation between both features

# %% [markdown]
# ### (8) Visualise the distribution of year and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# ### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# ### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
p=sns.displot(gapminder, x="year",y='lifeExp',hue='continent',height=4, aspect=1.5)
p.fig.set_dpi(150)
p.fig.suptitle("Distribution of Year and Life Expectancy",fontsize=10)
# Out:
# Text(0.5, 0.98, 'Distribution of Year and Life Expectancy')

# %% [markdown]
# The distribution of life expectancy is not normal and there is more then one peak in this distribution so its bimodel distribution and the mode of this distrbution is 70 and mean is also close to it but distrbution is not skewed.

# %%
sns.set(rc = {'figure.figsize':(15,8)})
r=sns.regplot(x="lifeExp", y="year", data=gapminder);
r.set_title("Regression Line  of Life Expectancy and Year",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Regression Line  of Life Expectancy and Year')

# %% [markdown]
# There is no relationship between these feature

# %% [markdown]
# ### (9) Use Boxplots or violinplots to visualise the distribution of change in life expectancy from 1952 to 2007.
#
# Hint tools from lab 6 may be helpful.

# %%
gapminder_filtered_9 = gapminder[gapminder['year'] >1952]
sns.boxplot(y='lifeExp',x='year',data=gapminder_filtered_9)

# %%
sns.violinplot(y='lifeExp',x='year',data=gapminder_filtered_9)

# %% [markdown]
# The boxplot  tell us the five number summary such as mean , median ,mode , spread, lower quartile and upper quartile so we see spread of 1977 is large as compared to othher and spread of 1992 is very large in violinplot and this is due to outliers

# %% [markdown]
# ### (10) Continue this analysis of the data. Include code cells, their outputs and markdown cells where you write about your findings. What patterns can you observe in the data?

# %%
#Distribution of first hunderd countries
sns.barplot(x=gapminder['country'].head(100),y=gapminder['gdpPercap'],data=gapminder)

# %%
#relationship and distribution of Gdp Per Capita and Life expectancy
sns.jointplot(x=gapminder['gdpPercap'], y= gapminder['lifeExp'],data=gapminder,kind='reg') #plot in the upper 
sns.jointplot(x=gapminder['gdpPercap'], y= gapminder['lifeExp'],data=gapminder,kind='hex') # plot in the below

# %%
# Correlation of different feature
sns.heatmap(gapminder.corr(), cmap='coolwarm',annot=True)

# %% [markdown]
# **Population with years**

# %%
f, ax = plt.subplots(1, 5, figsize=(20, 4))
sns.set_style('darkgrid')
pop_per_cont = gapminder.groupby(['continent', 'year']).sum()['pop'].unstack(level=0)
pop_per_cont

#Population over time, Plots and Labels
for i, x in enumerate(pop_per_cont.columns):
    ax[i].plot(pop_per_cont[x])
    ax[i].set_xlabel('Years')
    ax[0].set_ylabel('Population')
    ax[i].set_title(str(x))


plt.show()

# %% [markdown]
# **Life Expactancy with years**

# %%
life_per_cont = gapminder.groupby(['continent', 'year']).mean()['lifeExp'].unstack(level=0)


f, ax = plt.subplots(1, 5, figsize=(20, 4), sharey=True)
sns.set_style('darkgrid')


#Life Expectancy over time, Plots and Labels
for i, x in enumerate(life_per_cont.columns):
    ax[i].plot(life_per_cont[x])
    ax[i].set_xlabel('Years')
    ax[0].set_ylabel('Life Expectancy (years)')
    ax[i].set_title(str(x))


plt.show()
